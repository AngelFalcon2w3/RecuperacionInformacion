# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from bs4 import BeautifulSoup
import os

# %%
ruta = "/kaggle/input/pagina-html/Unstuffed Cabbage Roll Recipe.html"

# %%
# Usamos 'utf-8' para evitar problemas con tildes o caracteres especiales
with open(ruta, 'r', encoding='utf-8') as archivo:
    contenido_html = archivo.read()

# %%
soup = BeautifulSoup(contenido_html, 'html.parser')

# %%
print(contenido_html[:1000])
# Out:
# <!DOCTYPE html>
# <html id="recipeScTemplate_1-0" class="comp recipeScTemplate html mntl-html no-js taxlevel-4 " data-mm-ads-resource-version="2.2.101" data-ddm-standard-video="true" data-mm-video-resource-version="3.0.29" data-mm-myrecipes-resource-version="3.3.46" data-mantle-resource-version="4.2.273" data-allrecipes-resource-version="4.146.0" data-lazy-offset="200.0" data-ab="99,99,99,99,99,99,50,99,99,99,77,99,99,99,99,99,99,99,99,58,78,99,64,62" data-mm-transactional-resource-version="3.1.24" data-mm-digital-issues-resource-version="3.0.15" lang="en" data-tracking-container="true" data-resource-version="4.146.0" data-mm-recipes-resource-version="3.1.13"><!--
# <globe-environment environment="k8s-prod" application="allrecipes" dataCenter="us-east-1"/>
# -->
# <head class="loc head">
# <script type="text/javascript">
# var MMads = window.MMads || {};
# // Ad speed improvement flag - available early for sc-ads.js and right-rail.js
# MMads.useAdSpeedImprovement = false;</script>
# ...

# %%
# Extracting the recipe title
title = soup.find("title")
print(f"Título:{title.string}")
# Out:
# Título:Unstuffed Cabbage Roll Recipe

# %%
#score
#titulo
#description
#prep time
#cooking time
#total time
#servings
#ingredients
#directtions
#nutritions facts
#Reviews

# %%
score=soup.find("div", {"id":"mm-recipes-review-bar__rating_1-0"})
print(f"Calificación promedio de la receta: {score.string}")
# Out:
# Calificación promedio de la receta: 4.6

# %%
description=soup.find("p", {"class":"article-subheading text-utility-300"})
print(f"Description: \n{description.string}")
# Out:
# Description:
# This is an easy casserole made with ground beef, cabbage, garlic, and tomatoes. My kids don't even like cabbage, but they love this dish! Serve with rice for a comforting weeknight dinner. Also, the longer it stands the better it tastes!

# %%
prep_time=soup.find("div", {"class":"mm-recipes-details__value"})
print(f"Pre Time: {prep_time.string}")
# Out:
# Pre Time: 15 mins

# %%
def parsearReceta(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')

    score = soup.find("div", {"id": "mm-recipes-review-bar__rating_1-0"})
    prep_time = soup.find("div", {"class": "mm-recipes-details__value"})
    description = soup.find("p", {"class": "article-subheading text-utility-300"})
    title = soup.find("title")

    return {
        "score": score.get_text(strip=True) if score else None,
        "prep_time": prep_time.get_text(strip=True) if prep_time else None,
        "description": description.get_text(strip=True) if description else None,
        "title": title.get_text(strip=True) if title else None
    }

# %%
htmlparseado = parsearReceta(contenido_html)
htmlparseado
# Out:
# {'score': '4.6',
#  'prep_time': '15 mins',
#  'description': "This is an easy casserole made with ground beef, cabbage, garlic, and tomatoes. My kids don't even like cabbage, but they love this dish! Serve with rice for a comforting weeknight dinner. Also, the longer it stands the better it tastes!",
#  'title': 'Unstuffed Cabbage Roll Recipe'}

# %%
ruta_receta2 = "/kaggle/input/pagina-html/Chicken Cobbler Recipe.html"

# %%
with open(ruta_receta2, "r", encoding="utf-8") as archivo:
    contenido_html2 = archivo.read()
    soup = BeautifulSoup(contenido_html2, "html.parser")

# %%
receta2 = parsearReceta(contenido_html2)
receta2
# Out:
# {'score': '4.3',
#  'prep_time': '5 mins',
#  'description': "This viral TikTok chicken cobbler made with Red Lobster biscuit mix is incredibly easy to put together. We love this recipe from Matthew Bounds, aka @yourbarefootneighbor. Try it yourself to find out what everyone's raving about!",
#  'title': 'Chicken Cobbler Recipe'}
